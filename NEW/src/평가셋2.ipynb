# %%
import pandas as pd

# V2: Context 기반 및 평가 기준 강화 데이터셋 (총 20개)
data = [
    # ---------------------------------------------------------
    # 1. [기본] 난이도 하 (User Pref 없음, 상황에 충실)
    # ---------------------------------------------------------
    {
        "ID": 1, "Context": "Library (Quiet Zone, Morning)", "Decibel": "Silent", "Goal": "Deep Focus", 
        "User Pref": "None", 
        "Evaluation Criteria": "Must be: Instrumental, White noise, or Classical Piano. Constraint: No lyrics.",
        "Type": "기본", "Difficulty": "Low"
    },
    {
        "ID": 2, "Context": "Gym (Weight Room, Night)", "Decibel": "Loud", "Goal": "Cardio/Energy", 
        "User Pref": "None", 
        "Evaluation Criteria": "Must be: High BPM, EDM, or Workout Remix. Vibe: Energetic, Pumping.",
        "Type": "기본", "Difficulty": "Low"
    },
    {
        "ID": 3, "Context": "Home (Bedroom, Rainy Night)", "Decibel": "Quiet", "Goal": "Sleep Induction", 
        "User Pref": "None", 
        "Evaluation Criteria": "Must be: Rain sounds, Ambient, or Lullaby. Constraint: Very slow tempo, No sudden loud sounds.",
        "Type": "기본", "Difficulty": "Low"
    },

    # ---------------------------------------------------------
    # 2. [취향 반영] 난이도 중 (상황 + 취향 조화)
    # ---------------------------------------------------------
    {
        "ID": 4, "Context": "Cafe (Sunny Afternoon)", "Decibel": "Moderate", "Goal": "Relax/Read", 
        "User Pref": "Jazz", 
        "Evaluation Criteria": "Genre: Jazz (Vocal or Instrumental). Vibe: Cozy, Coffee shop atmosphere, Soft Saxophone.",
        "Type": "취향반영", "Difficulty": "Mid"
    },
    {
        "ID": 5, "Context": "Park (Jogging Track, Summer)", "Decibel": "Moderate", "Goal": "Running", 
        "User Pref": "K-Pop (NewJeans)", 
        "Evaluation Criteria": "Artist: NewJeans or similar refreshing K-Pop. Vibe: Upbeat, Youthful, Bright energy.",
        "Type": "취향반영", "Difficulty": "Mid"
    },
    {
        "ID": 6, "Context": "Co-working Space (Busy)", "Decibel": "Quiet", "Goal": "Coding/Work", 
        "User Pref": "Lo-fi", 
        "Evaluation Criteria": "Genre: Lo-fi Hip hop or Chillhop. Constraint: No distracting lyrics. Vibe: Productive, Repetitive.",
        "Type": "취향반영", "Difficulty": "Mid"
    },
    {
        "ID": 7, "Context": "Car (Highway Drive)", "Decibel": "Loud", "Goal": "Driving/Neutral", 
        "User Pref": "Pop Hits", 
        "Evaluation Criteria": "Genre: Trendy Pop (Billboard). Vibe: Rhythmic, Sing-along, Driving friendly.",
        "Type": "취향반영", "Difficulty": "Mid"
    },
    {
        "ID": 8, "Context": "Home (Late Night)", "Decibel": "Silent", "Goal": "Consolation (Sadness)", 
        "User Pref": "Ballad (IU)", 
        "Evaluation Criteria": "Artist: IU or Emotional Ballad. Vibe: Sad, Touching, Slow tempo piano.",
        "Type": "취향반영", "Difficulty": "Mid"
    },

    # ---------------------------------------------------------
    # 3. [충돌 해결] 난이도 상 (환경 vs 취향 -> 타협점 도출)
    # ---------------------------------------------------------
    {
        "ID": 9, "Context": "Library (Exam Period)", "Decibel": "Silent", "Goal": "Study", 
        "User Pref": "Heavy Metal", 
        "Evaluation Criteria": "Strategy: Change Genre or Sub-genre. Acceptable: Post-rock, Instrumental Metal, Ambient. Forbidden: Screaming vocals, Blast beats.",
        "Type": "충돌해결", "Difficulty": "High"
    },
    {
        "ID": 10, "Context": "Gym (Powerlifting)", "Decibel": "Loud", "Goal": "Strength Training", 
        "User Pref": "Classical", 
        "Evaluation Criteria": "Strategy: Match Energy. Acceptable: Epic Orchestral, Trailer Music, Fast-tempo Strings (e.g., Vivaldi Storm). Forbidden: Slow Adagio.",
        "Type": "충돌해결", "Difficulty": "High"
    },
    {
        "ID": 11, "Context": "Home (Bedtime)", "Decibel": "Quiet", "Goal": "Sleep", 
        "User Pref": "Hip-hop", 
        "Evaluation Criteria": "Strategy: Remove Lyrics/Aggression. Acceptable: Lo-fi Hip hop, Jazz-hop, Slow Jam Instrumentals. Forbidden: Trap, Gangsta Rap.",
        "Type": "충돌해결", "Difficulty": "High"
    },
    {
        "ID": 12, "Context": "Co-working Space", "Decibel": "Quiet", "Goal": "Deep Work", 
        "User Pref": "K-Pop (Dance)", 
        "Evaluation Criteria": "Strategy: Acoustic/Piano Arrange. Acceptable: Piano covers of K-Pop, Soft versions. Forbidden: Original dance tracks with heavy bass.",
        "Type": "충돌해결", "Difficulty": "High"
    },
    {
        "ID": 13, "Context": "Cafe (Lounge)", "Decibel": "Moderate", "Goal": "Relax", 
        "User Pref": "EDM", 
        "Evaluation Criteria": "Strategy: Downtempo. Acceptable: Tropical House, Chill House, Lounge Music. Forbidden: Big Room Festival EDM.",
        "Type": "충돌해결", "Difficulty": "High"
    },
    {
        "ID": 14, "Context": "Park (Sunset)", "Decibel": "Moderate", "Goal": "Consolation", 
        "User Pref": "Rock", 
        "Evaluation Criteria": "Strategy: Soften the tone. Acceptable: Soft Rock, Acoustic Rock, Britpop (e.g., Oasis). Forbidden: Hard Rock, Metal.",
        "Type": "충돌해결", "Difficulty": "High"
    },

    # ---------------------------------------------------------
    # 4. [특수 상황] 소음 대응 및 감정 분석
    # ---------------------------------------------------------
    {
        "ID": 15, "Context": "Subway (Rush Hour)", "Decibel": "Very Loud", "Goal": "Focus/Reading", 
        "User Pref": "Classical", 
        "Evaluation Criteria": "Strategy: Noise Masking. Acceptable: Cello solos (Deep frequencies), Steady rhythm. Vibe: Immersive.",
        "Type": "소음대응", "Difficulty": "High"
    },
    {
        "ID": 16, "Context": "Home (Alone)", "Decibel": "Moderate", "Goal": "Stress Relief (Venting Anger)", 
        "User Pref": "Rock", 
        "Evaluation Criteria": "Goal: Catharsis. Acceptable: Grunge, Punk Rock, Hard Rock. Vibe: Aggressive, Loud, Fast.",
        "Type": "감정분석", "Difficulty": "Mid"
    },
    {
        "ID": 17, "Context": "Home (Night)", "Decibel": "Moderate", "Goal": "Composure (Calming Anger)", 
        "User Pref": "Classical", 
        "Evaluation Criteria": "Goal: Sublimation. Acceptable: Dramatic Classical (Wagner, Rachmaninoff). Vibe: Intense but structured, Majestic.",
        "Type": "감정분석", "Difficulty": "High"
    },
    {
        "ID": 18, "Context": "Moving Day (Physical Labor)", "Decibel": "Loud", "Goal": "Active/Energy", 
        "User Pref": "Hip-hop", 
        "Evaluation Criteria": "Genre: Boom Bap or Old School. Vibe: Rhythmic, Steady beat for working, Motivating.",
        "Type": "감정분석", "Difficulty": "Mid"
    },
    {
        "ID": 19, "Context": "Cafe (Quiet Corner)", "Decibel": "Moderate", "Goal": "Neutral/Rest", 
        "User Pref": "Indie", 
        "Evaluation Criteria": "Genre: Indie Pop/Folk. Vibe: Acoustic, Easy listening, Calm.",
        "Type": "일반", "Difficulty": "Low"
    },
    {
        "ID": 20, "Context": "Library (Study Room)", "Decibel": "Silent", "Goal": "Deep Focus", 
        "User Pref": "Podcast (Talk Show)", 
        "Evaluation Criteria": "Conflict: Voice vs Focus. Action: REJECT user pref or suggest Instrumental/Binaural Beats. Forbidden: Talk shows.",
        "Type": "충돌해결", "Difficulty": "High"
    }
]

# DataFrame 생성
df_v2 = pd.DataFrame(data)

# 컬럼 순서 재배치 (가독성 위주)
cols = [
    "ID", "Type", "Difficulty", 
    "Context", "Goal", "User Pref", "Decibel", 
    "Evaluation Criteria"
]
df_v2 = df_v2[cols]

# CSV 파일로 저장
file_name = "evaluation_set_v2_criteria.csv"
df_v2.to_csv(file_name, index=False, encoding="utf-8-sig")

print(f" '{file_name}' 파일 생성 완료!")
print(f"총 {len(df_v2)}개의 케이스가 'Evaluation Criteria' 형식으로 업데이트되었습니다.")
# Out:
#  'evaluation_set_v2_criteria.csv' 파일 생성 완료!
# 총 20개의 케이스가 'Evaluation Criteria' 형식으로 업데이트되었습니다.
